# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations

lats = np.random.uniform(low = -90.000, high=90.000, size = 2000)

lngs = np.random.uniform(low=-90.000, high=90.000, size = 2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities=[]

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 759

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=d563333163df90649d97c53a213e47d1

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country= city_weather["sys"]["country"]
        city_description=city_weather["weather"][0]["description"]
          
            
        # Append the city information into the city_data list
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Description": city_description})
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | port alfred
# Processing Record 2 of Set 1 | qorveh
# Processing Record 3 of Set 1 | maceio
# Processing Record 4 of Set 1 | yenagoa
# Processing Record 5 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 6 of Set 1 | hithadhoo
# Processing Record 7 of Set 1 | east london
# Processing Record 8 of Set 1 | toulepleu
# City not found. Skipping...
# Processing Record 9 of Set 1 | mantamados
# Processing Record 10 of Set 1 | cap malheureux
# Processing Record 11 of Set 1 | bathsheba
# Processing Record 12 of Set 1 | bambous virieux
# Processing Record 13 of Set 1 | hamilton
# Processing Record 14 of Set 1 | ushuaia
# Processing Record 15 of Set 1 | ponta do sol
# Processing Record 16 of Set 1 | mirnyy
# Processing Record 17 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 18 of Set 1 | itarema
# Processing Record 19 of Set 1 | klaksvik
# Processing Record 20 of Set 1 | alta floresta
# Processing Record 21 of Set 1 | hermanus
# Processing Record 22 of Set 1 | morant bay
# Processing Record 23 of Set 1 | louisbourg
# City not found. Skipping...
# Processing Record 24 of Set 1 | corning
# Processing Record 25 of Set 1 | pisco
# Processing Record 26 of Set 1 | tokmak
# Processing Record 27 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 28 of Set 1 | kruisfontein
# Processing Record 29 of Set 1 | port-gentil
# Processing Record 30 of Set 1 | carinhanha
# Processing Record 31 of Set 1 | tasiilaq
# Processing Record 32 of Set 1 | lima
# Processing Record 33 of Set 1 | neftcala
# Processing Record 34 of Set 1 | dese
# Processing Record 35 of Set 1 | upernavik
# Processing Record 36 of Set 1 | senneterre
# Processing Record 37 of Set 1 | turayf
# Processing Record 38 of Set 1 | saint-philippe
# Processing Record 39 of Set 1 | esna
# Processing Record 40 of Set 1 | buqayq
# City not found. Skipping...
# Processing Record 41 of Set 1 | muisne
# Processing Record 42 of Set 1 | bredasdorp
# Processing Record 43 of Set 1 | busselton
# Processing Record 44 of Set 1 | conceicao do araguaia
# Processing Record 45 of Set 1 | kavaratti
# Processing Record 46 of Set 1 | almeria
# Processing Record 47 of Set 1 | buraydah
# Processing Record 48 of Set 1 | victoria
# Processing Record 49 of Set 1 | tsiroanomandidy
# Processing Record 50 of Set 1 | cape town
# Processing Record 1 of Set 2 | faya
# Processing Record 2 of Set 2 | cidreira
# Processing Record 3 of Set 2 | guane
# Processing Record 4 of Set 2 | crab hill
# City not found. Skipping...
# Processing Record 5 of Set 2 | dikson
# Processing Record 6 of Set 2 | iqaluit
# Processing Record 7 of Set 2 | punta arenas
# Processing Record 8 of Set 2 | gat
# Processing Record 9 of Set 2 | clyde river
# Processing Record 10 of Set 2 | yadgir
# Processing Record 11 of Set 2 | tuggurt
# City not found. Skipping...
# Processing Record 12 of Set 2 | richmond
# Processing Record 13 of Set 2 | los llanos de aridane
# Processing Record 14 of Set 2 | ribeira grande
# Processing Record 15 of Set 2 | khorramabad
# Processing Record 16 of Set 2 | saraland
# Processing Record 17 of Set 2 | kuusamo
# Processing Record 18 of Set 2 | waddan
# Processing Record 19 of Set 2 | buchanan
# Processing Record 20 of Set 2 | emirdag
# Processing Record 21 of Set 2 | prieska
# Processing Record 22 of Set 2 | barawe
# City not found. Skipping...
# Processing Record 23 of Set 2 | berlevag
# Processing Record 24 of Set 2 | chernushka
# Processing Record 25 of Set 2 | arraial do cabo
# Processing Record 26 of Set 2 | alfonsine
# Processing Record 27 of Set 2 | kollam
# Processing Record 28 of Set 2 | port blair
# Processing Record 29 of Set 2 | san cristobal
# Processing Record 30 of Set 2 | jaen
# Processing Record 31 of Set 2 | rypefjord
# Processing Record 32 of Set 2 | saint andrews
# Processing Record 33 of Set 2 | korla
# Processing Record 34 of Set 2 | saint-pierre
# Processing Record 35 of Set 2 | solvychegodsk
# Processing Record 36 of Set 2 | kudahuvadhoo
# Processing Record 37 of Set 2 | bushehr
# Processing Record 38 of Set 2 | bukama
# Processing Record 39 of Set 2 | strezhevoy
# Processing Record 40 of Set 2 | saint george
# Processing Record 41 of Set 2 | bollnas
# Processing Record 42 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 43 of Set 2 | mercedes
# Processing Record 44 of Set 2 | mar del plata
# Processing Record 45 of Set 2 | conceicao da barra
# Processing Record 46 of Set 2 | abong mbang
# Processing Record 47 of Set 2 | hambantota
# Processing Record 48 of Set 2 | ambikapur
# Processing Record 49 of Set 2 | jamestown
# Processing Record 50 of Set 2 | jizan
# Processing Record 1 of Set 3 | codrington
# Processing Record 2 of Set 3 | uvinza
# Processing Record 3 of Set 3 | kletskaya
# Processing Record 4 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 5 of Set 3 | hualmay
# Processing Record 6 of Set 3 | grootfontein
# Processing Record 7 of Set 3 | port elizabeth
# Processing Record 8 of Set 3 | aqtobe
# Processing Record 9 of Set 3 | penzance
# Processing Record 10 of Set 3 | riyadh
# Processing Record 11 of Set 3 | morlaix
# Processing Record 12 of Set 3 | nicoya
# Processing Record 13 of Set 3 | cabedelo
# Processing Record 14 of Set 3 | kamina
# Processing Record 15 of Set 3 | rocha
# Processing Record 16 of Set 3 | sao filipe
# Processing Record 17 of Set 3 | orbetello
# Processing Record 18 of Set 3 | nouadhibou
# Processing Record 19 of Set 3 | koutiala
# Processing Record 20 of Set 3 | mirabad
# Processing Record 21 of Set 3 | ostrovnoy
# Processing Record 22 of Set 3 | necochea
# Processing Record 23 of Set 3 | husavik
# Processing Record 24 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 25 of Set 3 | souillac
# Processing Record 26 of Set 3 | mahebourg
# Processing Record 27 of Set 3 | grand gaube
# Processing Record 28 of Set 3 | saldanha
# Processing Record 29 of Set 3 | laguna
# Processing Record 30 of Set 3 | salalah
# Processing Record 31 of Set 3 | lebu
# Processing Record 32 of Set 3 | haifa
# Processing Record 33 of Set 3 | nyimba
# Processing Record 34 of Set 3 | cuamba
# Processing Record 35 of Set 3 | kuminskiy
# Processing Record 36 of Set 3 | calabar
# Processing Record 37 of Set 3 | kondinskoye
# Processing Record 38 of Set 3 | salinas
# Processing Record 39 of Set 3 | miraflores
# Processing Record 40 of Set 3 | brae
# Processing Record 41 of Set 3 | sakakah
# Processing Record 42 of Set 3 | barranca
# Processing Record 43 of Set 3 | piacabucu
# Processing Record 44 of Set 3 | balkanabat
# Processing Record 45 of Set 3 | narsaq
# Processing Record 46 of Set 3 | pyatovskiy
# Processing Record 47 of Set 3 | mocuba
# Processing Record 48 of Set 3 | chaman
# Processing Record 49 of Set 3 | la seyne-sur-mer
# Processing Record 50 of Set 3 | lalibela
# Processing Record 1 of Set 4 | kyshtovka
# Processing Record 2 of Set 4 | nalut
# Processing Record 3 of Set 4 | santana do livramento
# Processing Record 4 of Set 4 | vila velha
# Processing Record 5 of Set 4 | fene
# Processing Record 6 of Set 4 | bosaso
# Processing Record 7 of Set 4 | stepnyak
# Processing Record 8 of Set 4 | coria
# Processing Record 9 of Set 4 | bud
# Processing Record 10 of Set 4 | santo antonio do ica
# Processing Record 11 of Set 4 | ubrique
# Processing Record 12 of Set 4 | colesberg
# Processing Record 13 of Set 4 | verkhnyaya inta
# Processing Record 14 of Set 4 | vuktyl
# Processing Record 15 of Set 4 | bengkulu
# Processing Record 16 of Set 4 | lagos
# Processing Record 17 of Set 4 | kyaka
# Processing Record 18 of Set 4 | georgetown
# Processing Record 19 of Set 4 | kantunilkin
# Processing Record 20 of Set 4 | chapleau
# Processing Record 21 of Set 4 | hofn
# Processing Record 22 of Set 4 | behshahr
# Processing Record 23 of Set 4 | meulaboh
# Processing Record 24 of Set 4 | sur
# Processing Record 25 of Set 4 | qaanaaq
# Processing Record 26 of Set 4 | clearwater
# Processing Record 27 of Set 4 | gornopravdinsk
# Processing Record 28 of Set 4 | camacha
# Processing Record 29 of Set 4 | biu
# Processing Record 30 of Set 4 | grivenskaya
# Processing Record 31 of Set 4 | raga
# Processing Record 32 of Set 4 | tartagal
# Processing Record 33 of Set 4 | besancon
# Processing Record 34 of Set 4 | rehoboth
# Processing Record 35 of Set 4 | chicama
# Processing Record 36 of Set 4 | ponta delgada
# Processing Record 37 of Set 4 | yazd
# Processing Record 38 of Set 4 | tupanatinga
# Processing Record 39 of Set 4 | kisangani
# Processing Record 40 of Set 4 | antofagasta
# Processing Record 41 of Set 4 | morondava
# Processing Record 42 of Set 4 | duki
# Processing Record 43 of Set 4 | touros
# Processing Record 44 of Set 4 | chuy
# Processing Record 45 of Set 4 | punta gorda
# Processing Record 46 of Set 4 | umm kaddadah
# Processing Record 47 of Set 4 | mondeville
# Processing Record 48 of Set 4 | hargeysa
# Processing Record 49 of Set 4 | mahemdavad
# Processing Record 50 of Set 4 | abu kamal
# Processing Record 1 of Set 5 | pandharpur
# Processing Record 2 of Set 5 | semey
# Processing Record 3 of Set 5 | mad
# Processing Record 4 of Set 5 | toliary
# City not found. Skipping...
# Processing Record 5 of Set 5 | lubaczow
# Processing Record 6 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 7 of Set 5 | luau
# Processing Record 8 of Set 5 | torbay
# Processing Record 9 of Set 5 | longyearbyen
# Processing Record 10 of Set 5 | caravelas
# Processing Record 11 of Set 5 | grindavik
# Processing Record 12 of Set 5 | bulawayo
# Processing Record 13 of Set 5 | tazovskiy
# Processing Record 14 of Set 5 | pedernales
# Processing Record 15 of Set 5 | san ramon
# Processing Record 16 of Set 5 | paamiut
# Processing Record 17 of Set 5 | adrar
# Processing Record 18 of Set 5 | olafsvik
# Processing Record 19 of Set 5 | nkhotakota
# Processing Record 20 of Set 5 | mariakani
# Processing Record 21 of Set 5 | sorland
# Processing Record 22 of Set 5 | gourcy
# Processing Record 23 of Set 5 | andselv
# City not found. Skipping...
# Processing Record 24 of Set 5 | jaciara
# Processing Record 25 of Set 5 | ouallam
# Processing Record 26 of Set 5 | sarankhola
# Processing Record 27 of Set 5 | makinsk
# Processing Record 28 of Set 5 | una
# Processing Record 29 of Set 5 | salamanca
# Processing Record 30 of Set 5 | pontes e lacerda
# Processing Record 31 of Set 5 | ust-tsilma
# Processing Record 32 of Set 5 | odweyne
# Processing Record 33 of Set 5 | garhi khairo
# Processing Record 34 of Set 5 | calama
# Processing Record 35 of Set 5 | kutum
# Processing Record 36 of Set 5 | coari
# Processing Record 37 of Set 5 | semnan
# Processing Record 38 of Set 5 | kolokani
# Processing Record 39 of Set 5 | dingle
# Processing Record 40 of Set 5 | saran
# Processing Record 41 of Set 5 | westminster
# Processing Record 42 of Set 5 | nyrob
# Processing Record 43 of Set 5 | yuzhnyy
# Processing Record 44 of Set 5 | ginir
# Processing Record 45 of Set 5 | carballo
# Processing Record 46 of Set 5 | cascais
# Processing Record 47 of Set 5 | quatre cocos
# Processing Record 48 of Set 5 | quelimane
# Processing Record 49 of Set 5 | bouake
# Processing Record 50 of Set 5 | matara
# Processing Record 1 of Set 6 | kralendijk
# Processing Record 2 of Set 6 | pangnirtung
# Processing Record 3 of Set 6 | dundee
# Processing Record 4 of Set 6 | moncao
# Processing Record 5 of Set 6 | mangan
# Processing Record 6 of Set 6 | puerto leguizamo
# Processing Record 7 of Set 6 | rio grande
# Processing Record 8 of Set 6 | dhaulpur
# Processing Record 9 of Set 6 | kulhudhuffushi
# Processing Record 10 of Set 6 | namibe
# Processing Record 11 of Set 6 | vardo
# Processing Record 12 of Set 6 | san luis
# Processing Record 13 of Set 6 | goderich
# Processing Record 14 of Set 6 | uyovu
# Processing Record 15 of Set 6 | den helder
# Processing Record 16 of Set 6 | salinopolis
# Processing Record 17 of Set 6 | puerto ayora
# Processing Record 18 of Set 6 | impfondo
# Processing Record 19 of Set 6 | vredendal
# Processing Record 20 of Set 6 | jalingo
# Processing Record 21 of Set 6 | rorvik
# Processing Record 22 of Set 6 | tibati
# Processing Record 23 of Set 6 | carnarvon
# Processing Record 24 of Set 6 | ugoofaaru
# Processing Record 25 of Set 6 | progreso
# Processing Record 26 of Set 6 | bankfoot
# Processing Record 27 of Set 6 | videira
# Processing Record 28 of Set 6 | gulmarg
# Processing Record 29 of Set 6 | salisbury
# Processing Record 30 of Set 6 | dalbandin
# Processing Record 31 of Set 6 | kokkola
# Processing Record 32 of Set 6 | cumaribo
# City not found. Skipping...
# Processing Record 33 of Set 6 | lexington
# Processing Record 34 of Set 6 | sao joao da barra
# Processing Record 35 of Set 6 | arlit
# Processing Record 36 of Set 6 | upata
# Processing Record 37 of Set 6 | venezuela
# Processing Record 38 of Set 6 | ribeirao do pinhal
# City not found. Skipping...
# Processing Record 39 of Set 6 | saint-louis
# Processing Record 40 of Set 6 | van
# Processing Record 41 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 42 of Set 6 | baghdad
# Processing Record 43 of Set 6 | shelburne
# Processing Record 44 of Set 6 | malakal
# Processing Record 45 of Set 6 | sigerfjord
# City not found. Skipping...
# Processing Record 46 of Set 6 | amapa
# Processing Record 47 of Set 6 | capim grosso
# Processing Record 48 of Set 6 | harper
# Processing Record 49 of Set 6 | bonavista
# Processing Record 50 of Set 6 | guayaramerin
# Processing Record 1 of Set 7 | fomboni
# Processing Record 2 of Set 7 | maracacume
# Processing Record 3 of Set 7 | ozgon
# City not found. Skipping...
# Processing Record 4 of Set 7 | mendoza
# Processing Record 5 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 6 of Set 7 | padang
# Processing Record 7 of Set 7 | zhanatas
# City not found. Skipping...
# Processing Record 8 of Set 7 | norderstedt
# Processing Record 9 of Set 7 | capitan bado
# Processing Record 10 of Set 7 | visby
# Processing Record 11 of Set 7 | harwich
# Processing Record 12 of Set 7 | kargasok
# Processing Record 13 of Set 7 | nanortalik
# Processing Record 14 of Set 7 | arrecife
# Processing Record 15 of Set 7 | awjilah
# Processing Record 16 of Set 7 | capua
# Processing Record 17 of Set 7 | mayor pablo lagerenza
# Processing Record 18 of Set 7 | wukari
# Processing Record 19 of Set 7 | funadhoo
# Processing Record 20 of Set 7 | manyana
# Processing Record 21 of Set 7 | puerto ayacucho
# Processing Record 22 of Set 7 | dolbeau
# City not found. Skipping...
# Processing Record 23 of Set 7 | broadford
# Processing Record 24 of Set 7 | barentu
# Processing Record 25 of Set 7 | axim
# Processing Record 26 of Set 7 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 27 of Set 7 | porto velho
# Processing Record 28 of Set 7 | el carmen
# Processing Record 29 of Set 7 | lubumbashi
# Processing Record 30 of Set 7 | sturgeon bay
# Processing Record 31 of Set 7 | valkeakoski
# Processing Record 32 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 33 of Set 7 | krasnoborsk
# Processing Record 34 of Set 7 | lakhnadon
# Processing Record 35 of Set 7 | bakau
# Processing Record 36 of Set 7 | antonina
# Processing Record 37 of Set 7 | biarritz
# Processing Record 38 of Set 7 | ancud
# Processing Record 39 of Set 7 | pangoa
# Processing Record 40 of Set 7 | azimur
# City not found. Skipping...
# Processing Record 41 of Set 7 | masjed-e soleyman
# City not found. Skipping...
# Processing Record 42 of Set 7 | puerto el triunfo
# Processing Record 43 of Set 7 | puerto asis
# Processing Record 44 of Set 7 | luderitz
# Processing Record 45 of Set 7 | faranah
# Processing Record 46 of Set 7 | itambacuri
# Processing Record 47 of Set 7 | maromitsa
# Processing Record 48 of Set 7 | lasa
# Processing Record 49 of Set 7 | nsoko
# Processing Record 50 of Set 7 | bridgetown
# Processing Record 1 of Set 8 | novopokrovka
# Processing Record 2 of Set 8 | los palacios
# Processing Record 3 of Set 8 | lulea
# Processing Record 4 of Set 8 | stornoway
# Processing Record 5 of Set 8 | konch
# Processing Record 6 of Set 8 | mecca
# Processing Record 7 of Set 8 | gamba
# Processing Record 8 of Set 8 | freetown
# Processing Record 9 of Set 8 | meridian
# Processing Record 10 of Set 8 | ipanguacu
# Processing Record 11 of Set 8 | kasongo-lunda
# Processing Record 12 of Set 8 | saint-augustin
# Processing Record 13 of Set 8 | mocambique
# City not found. Skipping...
# Processing Record 14 of Set 8 | grand river south east
# City not found. Skipping...
# Processing Record 15 of Set 8 | warrington
# Processing Record 16 of Set 8 | harbour breton
# Processing Record 17 of Set 8 | dalhousie
# Processing Record 18 of Set 8 | staryy nadym
# Processing Record 19 of Set 8 | areka
# Processing Record 20 of Set 8 | soria
# Processing Record 21 of Set 8 | lautaro
# Processing Record 22 of Set 8 | amarante do maranhao
# Processing Record 23 of Set 8 | kidal
# Processing Record 24 of Set 8 | novotroitskaya
# Processing Record 25 of Set 8 | ilulissat
# Processing Record 26 of Set 8 | boca do acre
# Processing Record 27 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 28 of Set 8 | peniche
# Processing Record 29 of Set 8 | marawi
# Processing Record 30 of Set 8 | mwanga
# Processing Record 31 of Set 8 | shchuchye
# City not found. Skipping...
# Processing Record 32 of Set 8 | kimberley
# Processing Record 33 of Set 8 | nova varos
# Processing Record 34 of Set 8 | karibib
# Processing Record 35 of Set 8 | xuddur
# Processing Record 36 of Set 8 | artyom
# Processing Record 37 of Set 8 | birkenfeld
# Processing Record 38 of Set 8 | tabou
# Processing Record 39 of Set 8 | avaton
# Processing Record 40 of Set 8 | beni suef
# Processing Record 41 of Set 8 | khorramshahr
# Processing Record 42 of Set 8 | castro
# Processing Record 43 of Set 8 | muravlenko
# Processing Record 44 of Set 8 | bilma
# Processing Record 45 of Set 8 | muyezerskiy
# Processing Record 46 of Set 8 | abu dhabi
# Processing Record 47 of Set 8 | shihezi
# Processing Record 48 of Set 8 | seaforth
# Processing Record 49 of Set 8 | nazilli
# Processing Record 50 of Set 8 | aguimes
# Processing Record 1 of Set 9 | umm lajj
# Processing Record 2 of Set 9 | altensteig
# Processing Record 3 of Set 9 | aras
# Processing Record 4 of Set 9 | gitarama
# Processing Record 5 of Set 9 | el ejido
# Processing Record 6 of Set 9 | orkney
# Processing Record 7 of Set 9 | aranos
# Processing Record 8 of Set 9 | la paz centro
# Processing Record 9 of Set 9 | mazyr
# Processing Record 10 of Set 9 | santiago de cuba
# Processing Record 11 of Set 9 | ushtobe
# Processing Record 12 of Set 9 | mehamn
# Processing Record 13 of Set 9 | naron
# Processing Record 14 of Set 9 | sambava
# Processing Record 15 of Set 9 | qandala
# Processing Record 16 of Set 9 | teguldet
# Processing Record 17 of Set 9 | mucurapo
# Processing Record 18 of Set 9 | mazagao
# Processing Record 19 of Set 9 | tawkar
# City not found. Skipping...
# Processing Record 20 of Set 9 | kangaatsiaq
# Processing Record 21 of Set 9 | muros
# Processing Record 22 of Set 9 | balkhash
# Processing Record 23 of Set 9 | honningsvag
# Processing Record 24 of Set 9 | capreol
# Processing Record 25 of Set 9 | biskamzha
# Processing Record 26 of Set 9 | koropion
# City not found. Skipping...
# Processing Record 27 of Set 9 | wahran
# City not found. Skipping...
# Processing Record 28 of Set 9 | yanam
# Processing Record 29 of Set 9 | moose factory
# Processing Record 30 of Set 9 | acarau
# Processing Record 31 of Set 9 | nueva loja
# Processing Record 32 of Set 9 | yar-sale
# Processing Record 33 of Set 9 | vestmannaeyjar
# Processing Record 34 of Set 9 | gao
# Processing Record 35 of Set 9 | andenes
# Processing Record 36 of Set 9 | dilla
# Processing Record 37 of Set 9 | doctor juan leon mallorquin
# Processing Record 38 of Set 9 | jiddah
# City not found. Skipping...
# Processing Record 39 of Set 9 | santa fe
# Processing Record 40 of Set 9 | alindao
# Processing Record 41 of Set 9 | cayenne
# Processing Record 42 of Set 9 | kamenka
# Processing Record 43 of Set 9 | zhetybay
# City not found. Skipping...
# Processing Record 44 of Set 9 | okahandja
# Processing Record 45 of Set 9 | qaqortoq
# Processing Record 46 of Set 9 | colares
# Processing Record 47 of Set 9 | tarauaca
# Processing Record 48 of Set 9 | greenville
# Processing Record 49 of Set 9 | cockburn town
# Processing Record 50 of Set 9 | aksarka
# Processing Record 1 of Set 10 | beloha
# Processing Record 2 of Set 10 | marcona
# City not found. Skipping...
# Processing Record 3 of Set 10 | menongue
# Processing Record 4 of Set 10 | mitsamiouli
# Processing Record 5 of Set 10 | channel-port aux basques
# Processing Record 6 of Set 10 | takoradi
# Processing Record 7 of Set 10 | kalashnikovo
# Processing Record 8 of Set 10 | sistranda
# Processing Record 9 of Set 10 | mahanje
# Processing Record 10 of Set 10 | urumqi
# Processing Record 11 of Set 10 | nova odesa
# Processing Record 12 of Set 10 | bako
# Processing Record 13 of Set 10 | pokhara
# Processing Record 14 of Set 10 | kahta
# Processing Record 15 of Set 10 | monrovia
# Processing Record 16 of Set 10 | nara
# Processing Record 17 of Set 10 | xudat
# Processing Record 18 of Set 10 | pala
# Processing Record 19 of Set 10 | nioro
# Processing Record 20 of Set 10 | san carlos de bariloche
# Processing Record 21 of Set 10 | atar
# Processing Record 22 of Set 10 | dasoguz
# Processing Record 23 of Set 10 | mahon
# Processing Record 24 of Set 10 | omboue
# Processing Record 25 of Set 10 | gazanjyk
# Processing Record 26 of Set 10 | eydhafushi
# Processing Record 27 of Set 10 | mumbwa
# Processing Record 28 of Set 10 | kharhial
# Processing Record 29 of Set 10 | santa maria
# Processing Record 30 of Set 10 | buta
# Processing Record 31 of Set 10 | igrim
# Processing Record 32 of Set 10 | jarjis
# City not found. Skipping...
# Processing Record 33 of Set 10 | dinsor
# City not found. Skipping...
# Processing Record 34 of Set 10 | alakurtti
# Processing Record 35 of Set 10 | alma
# Processing Record 36 of Set 10 | maniitsoq
# Processing Record 37 of Set 10 | grand-santi
# Processing Record 38 of Set 10 | saint-francois
# Processing Record 39 of Set 10 | aiken
# Processing Record 40 of Set 10 | mogadishu
# Processing Record 41 of Set 10 | coihaique
# Processing Record 42 of Set 10 | taoudenni
# Processing Record 43 of Set 10 | mahadday weyne
# City not found. Skipping...
# Processing Record 44 of Set 10 | traverse city
# Processing Record 45 of Set 10 | bandarbeyla
# Processing Record 46 of Set 10 | milove
# Processing Record 47 of Set 10 | beira
# Processing Record 48 of Set 10 | porto belo
# Processing Record 49 of Set 10 | richards bay
# Processing Record 50 of Set 10 | yarim
# Processing Record 1 of Set 11 | henties bay
# Processing Record 2 of Set 11 | xai-xai
# Processing Record 3 of Set 11 | pasni
# Processing Record 4 of Set 11 | paracuru
# Processing Record 5 of Set 11 | juybar
# Processing Record 6 of Set 11 | andevoranto
# City not found. Skipping...
# Processing Record 7 of Set 11 | hobyo
# Processing Record 8 of Set 11 | gunjur
# Processing Record 9 of Set 11 | tombouctou
# Processing Record 10 of Set 11 | puerto del rosario
# Processing Record 11 of Set 11 | dzhusaly
# City not found. Skipping...
# Processing Record 12 of Set 11 | constantine
# Processing Record 13 of Set 11 | tromso
# Processing Record 14 of Set 11 | louis trichardt
# Processing Record 15 of Set 11 | raudeberg
# Processing Record 16 of Set 11 | pimentel
# Processing Record 17 of Set 11 | mendi
# Processing Record 18 of Set 11 | port-cartier
# Processing Record 19 of Set 11 | praia
# Processing Record 20 of Set 11 | surt
# Processing Record 21 of Set 11 | lutry
# Processing Record 22 of Set 11 | margate
# Processing Record 23 of Set 11 | vestmanna
# Processing Record 24 of Set 11 | logansport
# Processing Record 25 of Set 11 | aligudarz
# Processing Record 26 of Set 11 | natal
# Processing Record 27 of Set 11 | akdepe
# Processing Record 28 of Set 11 | marquette
# Processing Record 29 of Set 11 | kano
# Processing Record 30 of Set 11 | soyo
# Processing Record 31 of Set 11 | techiman
# Processing Record 32 of Set 11 | krasnoselkup
# Processing Record 33 of Set 11 | gabu
# Processing Record 34 of Set 11 | rio gallegos
# Processing Record 35 of Set 11 | andapa
# Processing Record 36 of Set 11 | gazojak
# Processing Record 37 of Set 11 | lac-megantic
# Processing Record 38 of Set 11 | baldeo
# Processing Record 39 of Set 11 | puri
# Processing Record 40 of Set 11 | paragominas
# Processing Record 41 of Set 11 | great yarmouth
# Processing Record 42 of Set 11 | santa cruz cabralia
# Processing Record 43 of Set 11 | tahta
# Processing Record 44 of Set 11 | fevik
# Processing Record 45 of Set 11 | coquimbo
# Processing Record 46 of Set 11 | porto novo
# Processing Record 47 of Set 11 | bury saint edmunds
# City not found. Skipping...
# Processing Record 48 of Set 11 | alta
# Processing Record 49 of Set 11 | pali
# Processing Record 50 of Set 11 | birnin kebbi
# Processing Record 1 of Set 12 | tukrah
# Processing Record 2 of Set 12 | turinskaya sloboda
# Processing Record 3 of Set 12 | sorvag
# City not found. Skipping...
# Processing Record 4 of Set 12 | umba
# Processing Record 5 of Set 12 | comodoro rivadavia
# Processing Record 6 of Set 12 | vila do maio
# Processing Record 7 of Set 12 | sabha
# Processing Record 8 of Set 12 | yushala
# Processing Record 9 of Set 12 | sembe
# Processing Record 10 of Set 12 | tasbuget
# City not found. Skipping...
# Processing Record 11 of Set 12 | sint-gillis-waas
# Processing Record 12 of Set 12 | road town
# Processing Record 13 of Set 12 | luanda
# Processing Record 14 of Set 12 | saint anthony
# Processing Record 15 of Set 12 | verkhnebakanskiy
# Processing Record 16 of Set 12 | bismil
# Processing Record 17 of Set 12 | princeton
# Processing Record 18 of Set 12 | mozirje
# Processing Record 19 of Set 12 | minna
# Processing Record 20 of Set 12 | barahona
# Processing Record 21 of Set 12 | boda
# Processing Record 22 of Set 12 | talnakh
# Processing Record 23 of Set 12 | kanye
# Processing Record 24 of Set 12 | santa maria da vitoria
# Processing Record 25 of Set 12 | camargo
# Processing Record 26 of Set 12 | jumla
# Processing Record 27 of Set 12 | loandjili
# Processing Record 28 of Set 12 | tessalit
# Processing Record 29 of Set 12 | saurimo
# Processing Record 30 of Set 12 | sunndalsora
# Processing Record 31 of Set 12 | pedasi
# Processing Record 32 of Set 12 | kpandu
# Processing Record 33 of Set 12 | saint-joseph
# Processing Record 34 of Set 12 | gravdal
# Processing Record 35 of Set 12 | formoso do araguaia
# City not found. Skipping...
# Processing Record 36 of Set 12 | bonthe
# Processing Record 37 of Set 12 | basyanovskiy
# City not found. Skipping...
# Processing Record 38 of Set 12 | gorom-gorom
# Processing Record 39 of Set 12 | ambovombe
# Processing Record 40 of Set 12 | tarko-sale
# Processing Record 41 of Set 12 | ginda
# Processing Record 42 of Set 12 | nagorsk
# Processing Record 43 of Set 12 | buinsk
# Processing Record 44 of Set 12 | doha
# Processing Record 45 of Set 12 | new castle
# Processing Record 46 of Set 12 | nadym
# Processing Record 47 of Set 12 | bad durkheim
# Processing Record 48 of Set 12 | werda
# Processing Record 49 of Set 12 | pangody
# Processing Record 50 of Set 12 | nyanza
# Processing Record 1 of Set 13 | corralillo
# Processing Record 2 of Set 13 | mandiana
# Processing Record 3 of Set 13 | carlos chagas
# Processing Record 4 of Set 13 | gardan diwal
# City not found. Skipping...
# Processing Record 5 of Set 13 | jorpeland
# Processing Record 6 of Set 13 | jacareacanga
# Processing Record 7 of Set 13 | shepsi
# Processing Record 8 of Set 13 | calvinia
# Processing Record 9 of Set 13 | male
# Processing Record 10 of Set 13 | bahce
# Processing Record 11 of Set 13 | conde
# Processing Record 12 of Set 13 | inhambane
# Processing Record 13 of Set 13 | manaure
# Processing Record 14 of Set 13 | misratah
# Processing Record 15 of Set 13 | faruka
# Processing Record 16 of Set 13 | sao gabriel da cachoeira
# Processing Record 17 of Set 13 | nantucket
# Processing Record 18 of Set 13 | liure
# Processing Record 19 of Set 13 | muhos
# Processing Record 20 of Set 13 | troitsko-pechorsk
# Processing Record 21 of Set 13 | cacoal
# Processing Record 22 of Set 13 | nassau
# Processing Record 23 of Set 13 | westport
# Processing Record 24 of Set 13 | thompson
# Processing Record 25 of Set 13 | caucaia
# Processing Record 26 of Set 13 | talas
# Processing Record 27 of Set 13 | pauini
# Processing Record 28 of Set 13 | bouna
# Processing Record 29 of Set 13 | sirsaganj
# Processing Record 30 of Set 13 | kalmunai
# Processing Record 31 of Set 13 | oistins
# Processing Record 32 of Set 13 | isla mujeres
# Processing Record 33 of Set 13 | ostersund
# Processing Record 34 of Set 13 | kachikau
# City not found. Skipping...
# Processing Record 35 of Set 13 | urdzhar
# City not found. Skipping...
# Processing Record 36 of Set 13 | westpunt
# City not found. Skipping...
# Processing Record 37 of Set 13 | kortkeros
# Processing Record 38 of Set 13 | siderno
# Processing Record 39 of Set 13 | bartica
# Processing Record 40 of Set 13 | lagoa
# Processing Record 41 of Set 13 | praia da vitoria
# Processing Record 42 of Set 13 | biltine
# Processing Record 43 of Set 13 | lakselv
# Processing Record 44 of Set 13 | orebro
# Processing Record 45 of Set 13 | banepa
# Processing Record 46 of Set 13 | ozinki
# Processing Record 47 of Set 13 | alexandria
# Processing Record 48 of Set 13 | caucasia
# Processing Record 49 of Set 13 | vikulovo
# Processing Record 50 of Set 13 | aripuana
# Processing Record 1 of Set 14 | venado tuerto
# Processing Record 2 of Set 14 | gurgan
# City not found. Skipping...
# Processing Record 3 of Set 14 | hedaru
# Processing Record 4 of Set 14 | kankaanpaa
# Processing Record 5 of Set 14 | kindu
# Processing Record 6 of Set 14 | saint-lo
# Processing Record 7 of Set 14 | lusambo
# Processing Record 8 of Set 14 | villaviciosa
# Processing Record 9 of Set 14 | olinda
# Processing Record 10 of Set 14 | mariental
# Processing Record 11 of Set 14 | taman
# Processing Record 12 of Set 14 | pitimbu
# Processing Record 13 of Set 14 | brasilia
# Processing Record 14 of Set 14 | augusta
# Processing Record 15 of Set 14 | guantanamo
# Processing Record 16 of Set 14 | araouane
# Processing Record 17 of Set 14 | trincomalee
# Processing Record 18 of Set 14 | deep river
# Processing Record 19 of Set 14 | calabozo
# Processing Record 20 of Set 14 | camacari
# Processing Record 21 of Set 14 | bardiyah
# Processing Record 22 of Set 14 | iisalmi
# Processing Record 23 of Set 14 | campina verde
# Processing Record 24 of Set 14 | ilebo
# Processing Record 25 of Set 14 | mananjary
# Processing Record 26 of Set 14 | matadi
# Processing Record 27 of Set 14 | crixas
# Processing Record 28 of Set 14 | burica
# City not found. Skipping...
# Processing Record 29 of Set 14 | lokosovo
# Processing Record 30 of Set 14 | beauceville
# Processing Record 31 of Set 14 | huambo
# Processing Record 32 of Set 14 | navahrudak
# Processing Record 33 of Set 14 | ust-kulom
# Processing Record 34 of Set 14 | sao felix do xingu
# Processing Record 35 of Set 14 | soloneshnoye
# Processing Record 36 of Set 14 | maimon
# City not found. Skipping...
# Processing Record 37 of Set 14 | bubaque
# Processing Record 38 of Set 14 | esmoriz
# Processing Record 39 of Set 14 | ikwiriri
# Processing Record 40 of Set 14 | maloshuyka
# City not found. Skipping...
# Processing Record 41 of Set 14 | balykshi
# Processing Record 42 of Set 14 | cervo
# Processing Record 43 of Set 14 | bahia de caraquez
# Processing Record 44 of Set 14 | yefimovskiy
# City not found. Skipping...
# Processing Record 45 of Set 14 | kazalinsk
# City not found. Skipping...
# Processing Record 46 of Set 14 | rapar
# Processing Record 47 of Set 14 | krasni okny
# Processing Record 48 of Set 14 | tingrela
# City not found. Skipping...
# Processing Record 49 of Set 14 | avsyunino
# Processing Record 50 of Set 14 | tobol
# Processing Record 1 of Set 15 | agirish
# Processing Record 2 of Set 15 | jalu
# Processing Record 3 of Set 15 | cirpan
# City not found. Skipping...
# Processing Record 4 of Set 15 | khorixas
# Processing Record 5 of Set 15 | dawson
# Processing Record 6 of Set 15 | pavilosta
# Processing Record 7 of Set 15 | walvis bay
# Processing Record 8 of Set 15 | uruzgan
# Processing Record 9 of Set 15 | asimion
# Processing Record 10 of Set 15 | youkounkoun
# Processing Record 11 of Set 15 | villanueva de cordoba
# Processing Record 12 of Set 15 | rabo de peixe
# Processing Record 13 of Set 15 | mahibadhoo
# Processing Record 14 of Set 15 | strathpeffer
# Processing Record 15 of Set 15 | mandapam
# Processing Record 16 of Set 15 | albany
# Processing Record 17 of Set 15 | weligama
# Processing Record 18 of Set 15 | umm ruwabah
# City not found. Skipping...
# Processing Record 19 of Set 15 | vryheid
# Processing Record 20 of Set 15 | teguise
# Processing Record 21 of Set 15 | elista
# Processing Record 22 of Set 15 | jhang
# Processing Record 23 of Set 15 | semirom
# Processing Record 24 of Set 15 | kuznetsk
# Processing Record 25 of Set 15 | lichinga
# Processing Record 26 of Set 15 | salamiyah
# Processing Record 27 of Set 15 | dangriga
# Processing Record 28 of Set 15 | tubuala
# Processing Record 29 of Set 15 | tamandare
# Processing Record 30 of Set 15 | aden
# Processing Record 31 of Set 15 | puerto baquerizo moreno
# Processing Record 32 of Set 15 | viligili
# City not found. Skipping...
# Processing Record 33 of Set 15 | qurbus
# Processing Record 34 of Set 15 | asosa
# Processing Record 35 of Set 15 | barbar
# City not found. Skipping...
# Processing Record 36 of Set 15 | oussouye
# Processing Record 37 of Set 15 | pombas
# Processing Record 38 of Set 15 | lima duarte
# Processing Record 39 of Set 15 | ler
# Processing Record 40 of Set 15 | miranda
# Processing Record 41 of Set 15 | tignere
# Processing Record 42 of Set 15 | joacaba
# Processing Record 43 of Set 15 | toamasina
# Processing Record 44 of Set 15 | matagami
# Processing Record 45 of Set 15 | fort-shevchenko
# Processing Record 46 of Set 15 | general pico
# Processing Record 47 of Set 15 | tuni
# Processing Record 48 of Set 15 | skibbereen
# Processing Record 49 of Set 15 | fenelon falls
# Processing Record 50 of Set 15 | sosnovka
# Processing Record 1 of Set 16 | ilhabela
# Processing Record 2 of Set 16 | abu samrah
# Processing Record 3 of Set 16 | kapiri mposhi
# Processing Record 4 of Set 16 | luba
# Processing Record 5 of Set 16 | maldonado
# Processing Record 6 of Set 16 | malwan
# City not found. Skipping...
# Processing Record 7 of Set 16 | ikom
# Processing Record 8 of Set 16 | tabory
# Processing Record 9 of Set 16 | fraga
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 696

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#               City      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0      Port Alfred -33.5906  26.8910     74.57        84         100
# 1           Qorveh  35.1664  47.8045     39.36        68         100
# 2           Maceio  -9.6658 -35.7353     87.24        66           0
# 3          Yenagoa   4.9247   6.2642     79.88        76          41
# 4        Hithadhoo  -0.6000  73.0833     80.80        77         100
# 5      East London -33.0153  27.9116     70.74        94          20
# 6       Mantamados  39.3117  26.3339     53.65        81         100
# 7   Cap Malheureux -19.9842  57.6142     78.48        70           2
# 8        Bathsheba  13.2167 -59.5167     75.81        98          75
# 9  Bambous Virieux -20.3428  57.7575     78.22        78          40
#
#    Wind Speed Country                  Description
# 0        6.02      ZA                   light rain
# 1        4.38      IR              overcast clouds
# 2       16.11      BR                    clear sky
# 3        7.27      NG             scattered clouds
# 4       10.09      MV              overcast clouds
# 5       13.80      ZA                 thunderstorm
# 6       10.54      GR              overcast clouds
# 7       10.00      MU                    clear sky
# 8       17.27      BB  light intensity shower rain
# 9       11.50      MU             scattered clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
columns_reorder=["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"]


# Recreate the DataFrame by using the new column order
city_data_reorder = city_data_df.reindex(columns=columns_reorder)

# Display sample data
city_data_reorder
# Out:
#             City Country      Lat      Lng  Max Temp  Humidity  Cloudiness  \
# 0    Port Alfred      ZA -33.5906  26.8910     74.57        84         100
# 1         Qorveh      IR  35.1664  47.8045     39.36        68         100
# 2         Maceio      BR  -9.6658 -35.7353     87.24        66           0
# 3        Yenagoa      NG   4.9247   6.2642     79.88        76          41
# 4      Hithadhoo      MV  -0.6000  73.0833     80.80        77         100
# ..           ...     ...      ...      ...       ...       ...         ...
# 691         Luba      GQ   3.4568   8.5547     80.94        80           7
# 692    Maldonado      UY -34.6667 -54.9167     72.79        29           0
# 693         Ikom      NG   5.9667   8.7063     81.79        44           1
# 694       Tabory      RU  58.5198  64.5495     -2.00        93         100
# 695        Fraga      ES  41.5229   0.3489     50.92        98         100
#
#      Wind Speed  Current Description
# 0          6.02                  NaN
# 1          4.38                  NaN
# 2         16.11                  NaN
# 3          7.27                  NaN
# 4         10.09                  NaN
# ..          ...                  ...
# 691        7.16                  NaN
# 692       11.25                  NaN
# 693        1.54                  NaN
# 694        6.24                  NaN
# 695        5.32                  NaN
#
# [696 rows x 9 columns]

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_reorder.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description    float64
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data = "weather_Database"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data,index_label="City_ID")
